# %% [markdown]
# <a href="https://colab.research.google.com/github/rezaazimibar/AI-with-python/blob/master/testfolder/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
print("hello hello")
# Out:
# hello hello

# %%
print("test")
# Out:
# test
