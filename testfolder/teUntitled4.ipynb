# %% [markdown]
# <a href="https://colab.research.google.com/github/rezaazimibar/AI-with-python/blob/master/testfolder/teUntitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hel")
# Out:
# hel

# %%
print("helo")
# Out:
# helo

# %%
print("it is me")
# Out:
# it is me
